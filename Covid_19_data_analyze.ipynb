# %% [markdown]
# # **Covid 19 Data Analysis**

# %% [markdown]
# **Import necessary Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Loading the DataSet**

# %%
data = pd.read_csv('/content/4. covid_19_data.csv')
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# **Data Cleaning**

# %%
# Checking null values

data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# **Q.1) Show the number of Confirmed , Deaths and Recovered cases in each Region.**

# %%
data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region')['Confirmed']. sum() .sort_values (ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed', 'Recovered'].sum()
# Out:
# <ipython-input-12-22cb0e915030>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed', 'Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# **Q2) Remove all the records where Confirmed Cases is Less Than 10.**

# %%
data = data[~(data.Confirmed < 10)]

# %% [markdown]
# **Q.3) In which Region, maximum number of Confirmed cases were recorded ?**

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)

# %%
data.head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Name: Confirmed, dtype: int64

# %% [markdown]
# **Q.4) In which Region, minimum number of Deaths cases were recorded ?**

# %%
c = data.groupby('Region')['Deaths'].sum().sort_values(ascending = True)
c.head(10)
# Out:
# Region
# Laos                0
# Mongolia            0
# Mozambique          0
# Cambodia            0
# Fiji                0
# Namibia             0
# Nepal               0
# Madagascar          0
# Macau               0
# Papua New Guinea    0
# Name: Deaths, dtype: int64

# %% [markdown]
# **Q.5) How many Confirmed , Deaths & Recovered cases were reported from India till 29 April 2020 ?**

# %%
d = data[data['Region'] == 'India']
d
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
u = data[data['Region'] == 'Canada']
u
# Out:
#           Date                         State  Region  Confirmed  Deaths  \
# 183  4/29/2020                       Alberta  Canada       5165      87
# 193  4/29/2020              British Columbia  Canada       2087     109
# 203  4/29/2020  Diamond Princess cruise ship  Canada          0       1
# 215  4/29/2020                Grand Princess  Canada         13       0
# 246  4/29/2020                      Manitoba  Canada        275       6
# 259  4/29/2020                 New Brunswick  Canada        118       0
# 266  4/29/2020     Newfoundland and Labrador  Canada        258       3
# 272  4/29/2020         Northwest Territories  Canada          5       0
# 273  4/29/2020                   Nova Scotia  Canada        935      28
# 276  4/29/2020                       Ontario  Canada      16978    1153
# 279  4/29/2020          Prince Edward Island  Canada         27       0
# 282  4/29/2020                        Quebec  Canada      26610    1762
# ...

# %% [markdown]
# **Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.**

# %%
q = data.sort_values(by = ['Confirmed'], ascending = True)
q
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# **Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.**

# %%
z = data.sort_values(by = ['Recovered'], ascending = False)

# %%
z
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

# %% [markdown]
# ## **Done by SYED MIRAN**
